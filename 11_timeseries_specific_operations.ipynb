# %% [markdown]
# ## <strong> 11. 시계열 전용 연산

# %% [markdown]
# 필요한 라이브러리: ```yfinance```, ```pandas_datareader```

# %%
# !pip install yfinance
# Out:
# Collecting yfinance
#   Downloading yfinance-1.3.0-py2.py3-none-any.whl.metadata (6.1 kB)
# Requirement already satisfied: pandas>=1.3.0 in c:\users\cch03\anaconda3\lib\site-packages (from yfinance) (2.2.3)
# Requirement already satisfied: numpy>=1.16.5 in c:\users\cch03\anaconda3\lib\site-packages (from yfinance) (2.4.3)
# Requirement already satisfied: requests>=2.31 in c:\users\cch03\anaconda3\lib\site-packages (from yfinance) (2.32.3)
# Collecting multitasking>=0.0.7 (from yfinance)
#   Downloading multitasking-0.0.13-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: platformdirs>=2.0.0 in c:\users\cch03\anaconda3\lib\site-packages (from yfinance) (4.3.7)
# Requirement already satisfied: pytz>=2022.5 in c:\users\cch03\anaconda3\lib\site-packages (from yfinance) (2024.1)
# Requirement already satisfied: frozendict>=2.3.4 in c:\users\cch03\anaconda3\lib\site-packages (from yfinance) (2.4.2)
# Collecting peewee>=3.16.2 (from yfinance)
#   Downloading peewee-4.0.5-py3-none-any.whl.metadata (8.6 kB)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in c:\users\cch03\anaconda3\lib\site-packages (from yfinance) (4.12.3)
# Collecting curl_cffi>=0.15 (from yfinance)
#   Downloading curl_cffi-0.15.0-cp310-abi3-win_amd64.whl.metadata (18 kB)
# Requirement already satisfied: protobuf>=3.19.0 in c:\users\cch03\anaconda3\lib\site-packages (from yfinance) (5.29.3)
# Collecting websockets>=13.0 (from yfinance)
#   Downloading websockets-16.0-cp313-cp313-win_amd64.whl.metadata (7.0 kB)
# Requirement already satisfied: soupsieve>1.2 in c:\users\cch03\anaconda3\lib\site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.5)
# Collecting cffi>=2.0.0 (from curl_cffi>=0.15->yfinance)
#   Downloading cffi-2.0.0-cp313-cp313-win_amd64.whl.metadata (2.6 kB)
# Requirement already satisfied: certifi>=2024.2.2 in c:\users\cch03\anaconda3\lib\site-packages (from curl_cffi>=0.15->yfinance) (2025.4.26)
# Requirement already satisfied: rich in c:\users\cch03\anaconda3\lib\site-packages (from curl_cffi>=0.15->yfinance) (13.9.4)
# Requirement already satisfied: pycparser in c:\users\cch03\anaconda3\lib\site-packages (from cffi>=2.0.0->curl_cffi>=0.15->yfinance) (2.21)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\cch03\anaconda3\lib\site-packages (from pandas>=1.3.0->yfinance) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\cch03\anaconda3\lib\site-packages (from pandas>=1.3.0->yfinance) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\cch03\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas>=1.3.0->yfinance) (1.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\cch03\anaconda3\lib\site-packages (from requests>=2.31->yfinance) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\cch03\anaconda3\lib\site-packages (from requests>=2.31->yfinance) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\cch03\anaconda3\lib\site-packages (from requests>=2.31->yfinance) (2.3.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\cch03\anaconda3\lib\site-packages (from rich->curl_cffi>=0.15->yfinance) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\cch03\anaconda3\lib\site-packages (from rich->curl_cffi>=0.15->yfinance) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\cch03\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich->curl_cffi>=0.15->yfinance) (0.1.0)
# Downloading yfinance-1.3.0-py2.py3-none-any.whl (133 kB)
# Downloading curl_cffi-0.15.0-cp310-abi3-win_amd64.whl (1.7 MB)
#    ---------------------------------------- 0.0/1.7 MB ? eta -:--:--
#    ------------ --------------------------- 0.5/1.7 MB 2.3 MB/s eta 0:00:01
#    ------------------------------- -------- 1.3/1.7 MB 3.0 MB/s eta 0:00:01
#    ---------------------------------------- 1.7/1.7 MB 3.1 MB/s eta 0:00:00
# Downloading cffi-2.0.0-cp313-cp313-win_amd64.whl (183 kB)
# Downloading multitasking-0.0.13-py3-none-any.whl (16 kB)
# Downloading peewee-4.0.5-py3-none-any.whl (144 kB)
# Downloading websockets-16.0-cp313-cp313-win_amd64.whl (178 kB)
# Installing collected packages: peewee, multitasking, websockets, cffi, curl_cffi, yfinance
#
#    ---------------------------------------- 0/6 [peewee]
#    ---------------------------------------- 0/6 [peewee]
#    ---------------------------------------- 0/6 [peewee]
#    ------------- -------------------------- 2/6 [websockets]
#    ------------- -------------------------- 2/6 [websockets]
#    ------------- -------------------------- 2/6 [websockets]
#    ------------- -------------------------- 2/6 [websockets]
#   Attempting uninstall: cffi
#    ------------- -------------------------- 2/6 [websockets]
#     Found existing installation: cffi 1.17.1
#    ------------- -------------------------- 2/6 [websockets]
#    -------------------- ------------------- 3/6 [cffi]
#     Uninstalling cffi-1.17.1:
#    -------------------- ------------------- 3/6 [cffi]
#    -------------------- ------------------- 3/6 [cffi]
#    -------------------- ------------------- 3/6 [cffi]
#    -------------------- ------------------- 3/6 [cffi]
#    -------------------- ------------------- 3/6 [cffi]
#    -------------------- ------------------- 3/6 [cffi]
#    -------------------- ------------------- 3/6 [cffi]
#    -------------------- ------------------- 3/6 [cffi]
#    -------------------- ------------------- 3/6 [cffi]
#    -------------------- ------------------- 3/6 [cffi]
#    -------------------- ------------------- 3/6 [cffi]
#    -------------------- ------------------- 3/6 [cffi]
#    -------------------- ------------------- 3/6 [cffi]
#    -------------------- ------------------- 3/6 [cffi]
#    -------------------- ------------------- 3/6 [cffi]
#    -------------------- ------------------- 3/6 [cffi]
#    -------------------- ------------------- 3/6 [cffi]
#    -------------------- ------------------- 3/6 [cffi]
#    -------------------- ------------------- 3/6 [cffi]
#    -------------------- ------------------- 3/6 [cffi]
#    -------------------- ------------------- 3/6 [cffi]
#    -------------------- ------------------- 3/6 [cffi]
#    -------------------- ------------------- 3/6 [cffi]
#    -------------------- ------------------- 3/6 [cffi]
#    -------------------- ------------------- 3/6 [cffi]
#    -------------------- ------------------- 3/6 [cffi]
#    -------------------- ------------------- 3/6 [cffi]
#    -------------------- ------------------- 3/6 [cffi]
#    -------------------- ------------------- 3/6 [cffi]
#    -------------------- ------------------- 3/6 [cffi]
#    -------------------- ------------------- 3/6 [cffi]
#    -------------------- ------------------- 3/6 [cffi]
#    -------------------- ------------------- 3/6 [cffi]
#    -------------------- ------------------- 3/6 [cffi]
#    -------------------- ------------------- 3/6 [cffi]
#    -------------------- ------------------- 3/6 [cffi]
#    -------------------- ------------------- 3/6 [cffi]
#    -------------------- ------------------- 3/6 [cffi]
#    -------------------- ------------------- 3/6 [cffi]
#    -------------------- ------------------- 3/6 [cffi]
#    -------------------- ------------------- 3/6 [cffi]
#    -------------------- ------------------- 3/6 [cffi]
#    -------------------- ------------------- 3/6 [cffi]
#    -------------------- ------------------- 3/6 [cffi]
#    -------------------- ------------------- 3/6 [cffi]
#    -------------------- ------------------- 3/6 [cffi]
#    -------------------- ------------------- 3/6 [cffi]
#    -------------------- ------------------- 3/6 [cffi]
#    -------------------- ------------------- 3/6 [cffi]
#    -------------------- ------------------- 3/6 [cffi]
#    -------------------- ------------------- 3/6 [cffi]
#       Successfully uninstalled cffi-1.17.1
#    -------------------- ------------------- 3/6 [cffi]
#    -------------------- ------------------- 3/6 [cffi]
#    -------------------- ------------------- 3/6 [cffi]
#    -------------------------- ------------- 4/6 [curl_cffi]
#    -------------------------- ------------- 4/6 [curl_cffi]
#    -------------------------- ------------- 4/6 [curl_cffi]
#    --------------------------------- ------ 5/6 [yfinance]
#    --------------------------------- ------ 5/6 [yfinance]
#    --------------------------------- ------ 5/6 [yfinance]
#    ---------------------------------------- 6/6 [yfinance]
#
# Successfully installed cffi-2.0.0 curl_cffi-0.15.0 multitasking-0.0.13 peewee-4.0.5 websockets-16.0 yfinance-1.3.0

# %%
import yfinance as yf
import pandas as pd
from matplotlib import pyplot as plt

# %%
# 구글 주식 데이터 로딩
goog = yf.download("GOOG", start="2004-01-01", end="2024-12-31")
goog.head()
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price          Close      High       Low      Open     Volume
# Ticker          GOOG      GOOG      GOOG      GOOG       GOOG
# Date
# 2004-08-19  2.478783  2.570680  2.370580  2.470383  897427216
# 2004-08-20  2.675672  2.694694  2.482735  2.495333  458857488
# 2004-08-23  2.702599  2.803390  2.693953  2.735949  366857939
# 2004-08-24  2.590690  2.756947  2.558575  2.748054  306396159
# 2004-08-25  2.618606  2.668014  2.566233  2.592914  184645512

# %%
# [+] 종가(Close) 데이터만 사용하기
goog = ...
goog

# %%
# [+] Lineplot 시각화
goog.plot

# %% [markdown]
# #### <strong> 리샘플링(Resampling)
# + ```resample()```: 빈도를 기준으로 집계 연산
# + ```asfreq()```: 빈도 단위 별 데이터 선택

# %%
# [+] 다운샘플링: resample()
goog_downsampled = ...
goog_downsampled

# %%
fig, ax = plt.subplots(2, 1, sharey=True, figsize=(12, 6))
goog.plot(label='original', ax=ax[0])
ax[0].legend()
goog_downsampled.plot(label='downsampled', ax=ax[1])
ax[1].legend()
plt.tight_layout()

# %%
# [+] 다운샘플링: asfreq()
goog_downsampled = goog.asfreq('M')
print(goog_downsampled)

goog_downsampled.plot()
# Out:
# C:\Users\cch03\AppData\Local\Temp\ipykernel_19960\2305263628.py:2: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   goog_downsampled = goog.asfreq('M')
# Price            Close        High         Low        Open       Volume
# Ticker            GOOG        GOOG        GOOG        GOOG         GOOG
# Date
# 2004-08-31    2.528930    2.562033    2.523743    2.527202   98825037.0
# 2004-09-30    3.201616    3.268317    3.186794    3.209027  276468402.0
# 2004-10-31         NaN         NaN         NaN         NaN          NaN
# 2004-11-30    4.495602    4.520800    4.452865    4.464228  309154460.0
# 2004-12-31    4.762652    4.937802    4.756969    4.921745  307889737.0
# ...                ...         ...         ...         ...          ...
# 2024-07-31  171.935455  174.676105  170.515493  173.693044   15650200.0
# 2024-08-31         NaN         NaN         NaN         NaN          NaN
# 2024-09-30  166.235825  166.404853  163.700375  163.839575   14070100.0
# 2024-10-31  171.704422  177.401715  171.575159  173.722835   32801900.0
# 2024-11-30         NaN         NaN         NaN         NaN          NaN
#
# [244 rows x 5 columns]
# <Axes: xlabel='Date'>

# %%
# [+] 업샘플링: resample()
goog_upsampled = goog.resample ('12h').mean()
print(goog_upsampled)
# Out:
# Price                     Close        High         Low        Open  \
# Ticker                     GOOG        GOOG        GOOG        GOOG
# Date
# 2004-08-19 00:00:00    2.478783    2.570680    2.370580    2.470383
# 2004-08-19 12:00:00         NaN         NaN         NaN         NaN
# 2004-08-20 00:00:00    2.675672    2.694694    2.482735    2.495333
# 2004-08-20 12:00:00         NaN         NaN         NaN         NaN
# 2004-08-21 00:00:00         NaN         NaN         NaN         NaN
# ...                         ...         ...         ...         ...
# 2024-12-28 00:00:00         NaN         NaN         NaN         NaN
# 2024-12-28 12:00:00         NaN         NaN         NaN         NaN
# 2024-12-29 00:00:00         NaN         NaN         NaN         NaN
# 2024-12-29 12:00:00         NaN         NaN         NaN         NaN
# 2024-12-30 00:00:00  191.807632  192.892637  189.488300  189.990993
#
# Price                     Volume
# Ticker                      GOOG
# Date
# 2004-08-19 00:00:00  897427216.0
# 2004-08-19 12:00:00          NaN
# 2004-08-20 00:00:00  458857488.0
# 2004-08-20 12:00:00          NaN
# 2004-08-21 00:00:00          NaN
# ...                          ...
# 2024-12-28 00:00:00          NaN
# 2024-12-28 12:00:00          NaN
# 2024-12-29 00:00:00          NaN
# 2024-12-29 12:00:00          NaN
# 2024-12-30 00:00:00   12209500.0
#
# [14877 rows x 5 columns]

# %% [markdown]
# #### <strong> 시프팅(Shifting)
# + ```shift(periods)``` : ```periods``` 값 만큼 시계열 이동

# %%
# [+] 900일 뒤로 시프팅 적용
goog_shifted = goog.shi
goog_shifted

# %%
fig, ax = plt.subplots(2, 1, sharey=True, figsize=(12, 6))

# Legends and annotations
local_max = pd.to_datetime('2007-11-05')
offset = pd.Timedelta(900, 'D')

goog.plot(label='original', ax=ax[0])
ax[0].legend()
ax[0].get_xticklabels()[2].set(weight='heavy', color='red')
ax[0].axvline(local_max, alpha=0.3, color='red')

goog_shifted.plot(label='shifted 900 days', ax=ax[1])
ax[1].legend()
ax[1].get_xticklabels()[2].set(weight='heavy', color='red')
ax[1].axvline(local_max + offset, alpha=0.3, color='red')

plt.tight_layout()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 12
#       9 ax[0].get_xticklabels()[2].set(weight='heavy', color='red')
#      10 ax[0].axvline(local_max, alpha=0.3, color='red')
# ---> 12 goog_shifted.plot(label='shifted 900 days', ax=ax[1])
#      13 ax[1].legend()
#      14 ax[1].get_xticklabels()[2].set(weight='heavy', color='red')
#
# NameError: name 'goog_shifted' is not defined

# %%
# shifting 응용: 주가 변화율 계산
goog_shifted = goog.shift(periods=1) # [+] 시프팅
(goog - goog_shifted) / (goog_shifted)# [+] 주가 변화율 계산
# Out:
# Price          Close      High       Low      Open    Volume
# Ticker          GOOG      GOOG      GOOG      GOOG      GOOG
# Date
# 2004-08-19       NaN       NaN       NaN       NaN       NaN
# 2004-08-20  0.079430  0.048242  0.047311  0.010100 -0.488697
# 2004-08-23  0.010064  0.040337  0.085075  0.096426 -0.200497
# 2004-08-24 -0.041408 -0.016567 -0.050252  0.004424 -0.164810
# 2004-08-25  0.010775 -0.032258  0.002993 -0.056455 -0.397363
# ...              ...       ...       ...       ...       ...
# 2024-12-23  0.015703  0.012131  0.028224  0.037538 -0.663813
# 2024-12-24  0.008062  0.006005  0.018619  0.011029 -0.553042
# 2024-12-26 -0.002379  0.002479  0.003443  0.002906  0.161253
# 2024-12-27 -0.015525 -0.006863 -0.019901 -0.001372  0.858015
# 2024-12-30 -0.006957 -0.015346 -0.008397 -0.028529 -0.169026
#
# [5126 rows x 5 columns]

# %%
# shifting 응용: 차분 시계열 구하기
goog_diff = ...  # [+] 차분
print(goog_diff)

goog_diff.plot()

# %% [markdown]
# #### <strong> 윈도잉(Windowing)

# %%
# [+] 365일 단위 윈도잉
goog_rolled = ...
print(goog_rolled)

goog_rolled.mean().plot()

# %%
data = pd.DataFrame({'input': goog.values.flatten(),
                     # moving average
                     'one-year rolling_mean': goog_rolled.mean().values.flatten(), 
                     # standard deviation
                     'one-year rolling_std': goog_rolled.std().values.flatten()}, index=goog.index)
ax = data.plot(style=['-', '--', ':'])
ax.lines[0].set_alpha(0.3)
